# %%
# Librairies
import os
import pandas as pd
import numpy as np

# Modules
import climatic as clim
import dichotomy as dic
import watershed as wat
# Out:
# flopy is installed in C:\Users\alexa\miniconda3\envs\model\lib\site-packages\flopy

# %%
outlets = pd.read_csv("C:/Users/alexa/Dropbox/HydroModPy/outlets_norm.txt", sep='\t', header=None, engine='python')
dem_path="C:/Users/alexa/Dropbox/HydroModPy/MNT_TOPO_BATH_75m.tif"

# %%
outlet = outlets.loc[[0]]
site = outlet[[0]].values[0][0]

# %%
wat.extract_watershed(dem_path=dem_path, outlet=outlet, 
                      snap_dist=750, buff_dist=1000,
                      save_gis=True,box = True, out_path="C:/Users/alexa/Dropbox/HydroModPy/")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\model\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-6cf7d0e2ae7d> in <module>
#       1 wat.extract_watershed(dem_path=dem_path, outlet=outlet, box = True,
#       2                       snap_dist=750, buff_dist=1000,
# ----> 3                       save_gis=True, out_path="C:/Users/alexa/Dropbox/HydroModPy/")
#
# ~\Documents\GitHub\HydroModPy\src\watershed.py in __init__(self, dem_path, outlet, snap_dist, buff_dist, save_gis, box, tmp_path, out_path)
#      36
#      37                 if self.save_gis == True :
# ---> 38                         self.gis_path = self.out_path + self.outlet[0].values[0] + '/gis/'
#      39                 else:
#      40                         self.gis_path = self.tmp_path
#
# ~\miniconda3\envs\model\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\miniconda3\envs\model\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0

# %%
outlets.loc[[0]]
# Out:
#         0              1             2
# 0  vanlee  365397.645605  6.879713e+06
