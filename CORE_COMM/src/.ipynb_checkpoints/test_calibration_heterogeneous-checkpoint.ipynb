# %%
# Librairies
import os
import pandas as pd
import numpy as np

# Modules
import climatic as clim
import dichotomy as dic
import watershed as wat
import geology as geo
# Out:
# flopy is installed in C:\Users\alexa\miniconda3\envs\model\lib\site-packages\flopy

# %%
outlets = pd.read_csv("C:/Users/alexa/Dropbox/HydroModPy/outlets_norm.txt", sep='\t', header=None, engine='python')
dem_path="C:/Users/alexa/Dropbox/HydroModPy/MNT_TOPO_BATH_75m.tif"

# %%
outlet = outlets.loc[[0]]
site = outlet[[0]].values[0][0]

# %%
wat.extract_watershed(dem_path=dem_path, outlet=outlet, 
                      snap_dist=750, buff_dist=1000,
                      save_gis=True, box = True, out_path="C:/Users/alexa/Dropbox/HydroModPy/")

# %%
import geology as geo
dem = 'C:/Users/alexa/Dropbox/HydroModPy/vanlee/gis/watershed_buff_dem.tif'
output_path = 'C:/Users/alexa/Dropbox/HydroModPy/vanlee/gis/'
geo.structure(dem_path=dem, out_path= output_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-3b9cfe698b48> in <module>
#       1 import geology as geo
#       2 dem = 'C:/Users/alexa/Dropbox/HydroModPy/vanlee/gis/watershed_buff_dem.tif'
# ----> 3 geo.structure(dem_path=dem)
#
# ~\Documents\GitHub\HydroModPy\src\geology.py in __init__(self, dem_path, geo_path, out_path)
#      16                 self.structure_dem_path = out_path + 'GeoStructure.tif'
#      17                 self.land_sea_dem = out_path + 'Land_Sea.tif'
# ---> 18                 self.generate_structure_dem()
#      19
#      20         def generate_structure_dem(self):
#
# ~\Documents\GitHub\HydroModPy\src\geology.py in generate_structure_dem(self)
#      20         def generate_structure_dem(self):
#      21                 wbt.vector_polygons_to_raster(self.geo_path, self.structure_dem_path , field="CODE_LEG", nodata=None, base=self.dem_path)
# ---> 22                 wbt.vector_polygons_to_raster(self.geo_path, self.r_terre_mer, field="T_M_num", nodata=None, base=self.dem_path)
#      23                 st()
#      24                 dem_geo = gdal.Open(self.r_geo)
#
# AttributeError: 'structure' object has no attribute 'r_terre_mer'
